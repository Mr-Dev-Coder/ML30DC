# %% [markdown]
# # Day 22 of ML 30-Days Challenge

# %% [markdown]
# # Task
#
# **Model Evaluation Metrics (Regression)**: Learn about MAE, MSE, and R-squared. Add Root Mean Squared Error (RMSE) to your toolkit and understand how it penalizes large errors more heavily than MAE.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ###1. Generate Dataset

# %%
X, y = make_regression(n_samples=200, n_features=5, noise=10.0, random_state=42)
column=[f"feature_{i+1}" for i in range(X.shape[1])]

X_df = pd.DataFrame(X, columns=column)
y_df = pd.Series(y, name="target")

# %% [markdown]
# ###2. Import Functions and Build Pipeline

# %%
model = LinearRegression()
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("regressor", LinearRegression())
])

# %% [markdown]
# ###3. Run Cross-Validation

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42) # splits accordingly for 2..n times
scores = cross_val_score(pipeline, X_df, y_df, cv=kf)  # simple isn't it

scores
# Out:
# array([0.99019459, 0.98561754, 0.98820608, 0.98979421, 0.98792245])

# %% [markdown]
# ###4. Analyze Results

# %%
print("Scores for each fold:", scores)
print("Mean R^2 score:", scores.mean())
print("Standard deviation:", scores.std())
# Out:
# Scores for each fold: [0.99019459 0.98561754 0.98820608 0.98979421 0.98792245]
# Mean R^2 score: 0.9883469742163034
# Standard deviation: 0.001622222168604382
